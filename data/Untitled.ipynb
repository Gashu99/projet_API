# %%
import json
import pyshorteners
with open ("dataem1.json") as f:
    dataem1 = json.load(f)
with open ("dataem3.json") as f:
    dataem3 = json.load(f)
with open ("dataem2.json") as f:
    dataem2 = json.load(f)
locations = []
for occur in dataem3[150:163]:
    locations.append(occur["location"])
for i in range (len(dataem2)):
    dataem2[i]["location"] = locations[i]

rm = ["$",",","."]
tabprix = []
for d in dataem1:
    prix = (str(int(int(d["prix"].split("€")[0])*658.33)) + " CFA")
    tabprix.append(prix)

for i in range (len(dataem1)):
    if "€" in dataem1[i]["prix"]:
        dataem1[i]["prix"] = tabprix[i]
for d in dataem2:
    tabprix.append(str(int(d["prix"].split(".")[0].replace("$","").replace(",",""))*605) + " CFA")
for i in range (len(dataem2)):
    if "$" in dataem2[i]["prix"]:
        dataem2[i]["prix"] = tabprix[i]
dataem1et2 = dataem1 + dataem2
for d in dataem1et2:
    cd = {k : v for k,v in d.items() if k != "note"}

cdem3 = []
type_tiny = pyshorteners.Shortener()
for d in dataem3:
    occur = {}
    image    =  d["image"]
    location = d["location"]
    nom      = d["title"]
    prix     = d["price"][:-3].replace(" ","")
    
#    print((int(prix)))
    if prix[0].isnumeric() and int(prix) > 200000 and "Congélateur" not in nom and "laver" not in nom :
        occur ["image"] = short_url = type_tiny.tinyurl.short(image)    
        occur ["location"] = location 
        occur ["nom"] = nom      
        occur ["prix"] = prix + " CFA"     
    if occur != {}:
        cdem3.append(occur)

data = []
data = cdem3 + dataem1et2
with open("/home/nyto/Documents/scraping/data/data.json", "w") as f:
    f.write(json.dumps(data, ensure_ascii=False))

# %%
dataem1 # 13
# Out:
# [{'nom': 'Lave-linge séchant CANDY CSWS485TWMRE47',
#   'note': '4,5/5 (2 avis clients)',
#   'prix': '466€00',
#   'image': 'https://tinyurl.com/2y7m3phv'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '581€00',
#   'image': 'https://tinyurl.com/25uxyylg'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90T634DHE',
#   'note': '3/5 (1 avis clients)',
#   'prix': '622€00',
#   'image': 'https://tinyurl.com/2xvxqksy'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '649€00',
#   'image': 'https://tinyurl.com/2yyeweeu'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T684DLH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '693€00',
#   'image': 'https://tinyurl.com/28yvbs3o'},
#  {'nom': 'Lave-linge séchant SAMSUNG WD10T534DBW',
#   'note': '1/5 (1 avis clients)',
#   'prix': '899€00',
#   'image': 'https://tinyurl.com/22bamgwd'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80TA046TH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '545€00',
#   'image': 'https://tinyurl.com/2742pjmr'},
#  {'nom': 'Lave-linge frontal LG F51P12WH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '1099€00',
#   'image': 'https://tinyurl.com/238aw28b'},
#  {'nom': 'Lave-linge frontal LG F14V50WHS',
#   'note': 'no review',
#   'prix': '635€00',
#   'image': 'https://tinyurl.com/2cgzkqsz'},
#  {'nom': 'Lave-linge hublot HAIER HW09CP1439N',
#   'note': 'no review',
#   'prix': '473€00',
#   'image': 'https://tinyurl.com/26durlkl'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90TA046AX',
#   'note': '3,3/5 (3 avis clients)',
#   'prix': '601€00',
#   'image': 'https://tinyurl.com/2xna5aga'},
#  {'nom': 'Lave-linge hublot CANDY CO12105TE1S',
#   'note': '3/5 (2 avis clients)',
#   'prix': '369€99',
#   'image': 'https://tinyurl.com/28qqt6fs'},
#  {'nom': 'Lave-linge top BRANDT BT652AT',
#   'note': 'no review',
#   'prix': '479€00',
#   'image': 'https://tinyurl.com/27qqzmmh'},
#  {'nom': 'Lave-linge top VEDETTE LTV652B2',
#   'note': 'no review',
#   'prix': '468€00',
#   'image': 'https://tinyurl.com/28avenmu'},
#  {'nom': 'Lave-linge top VEDETTE VLT1255W2',
#   'note': 'no review',
#   'prix': '440€00',
#   'image': 'https://tinyurl.com/2bjwg3m3'},
#  {'nom': 'Lave-linge hublot INDESIT EWC71252WFRN',
#   'note': 'no review',
#   'prix': '422€00',
#   'image': 'https://tinyurl.com/2dj4re3q'},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GV',
#   'note': 'no review',
#   'prix': '1031€00',
#   'image': 'https://tinyurl.com/2bc8rqac'},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GW',
#   'note': 'no review',
#   'prix': '1199€00',
#   'image': 'https://tinyurl.com/265qyg6e'},
#  {'nom': 'Lave-linge frontal CANDY CSS1413TWME147',
#   'note': '4/5 (1 avis clients)',
#   'prix': '546€00',
#   'image': 'https://tinyurl.com/2axmzafv'},
#  {'nom': 'Lave-linge hublot VEDETTE LFVQ104W',
#   'note': '5/5 (1 avis clients)',
#   'prix': '489€99',
#   'image': 'https://tinyurl.com/26s2mo3l'},
#  {'nom': 'Lave-linge séchant CANDY CSWS4128TWME47',
#   'note': 'no review',
#   'prix': '796€00',
#   'image': 'https://tinyurl.com/2b3mtpqm'},
#  {'nom': 'Lave-linge séchant CANDY CSWS4962DWE1S',
#   'note': 'no review',
#   'prix': '540€00',
#   'image': 'https://tinyurl.com/2xumaadl'},
#  {'nom': 'Lave-linge hublot INDESIT BWA101283XWFRN',
#   'note': '5/5 (1 avis clients)',
#   'prix': '399€99',
#   'image': 'https://tinyurl.com/2bq26zbw'},
#  {'nom': 'Lave-linge hublot BRANDT WFB180W',
#   'note': 'no review',
#   'prix': '446€00',
#   'image': 'https://tinyurl.com/296aqdax'},
#  {'nom': 'Lave-linge hublot BRANDT WFB124QW',
#   'note': '4/5 (1 avis clients)',
#   'prix': '548€00',
#   'image': 'https://tinyurl.com/2anu4q67'},
#  {'nom': 'Lave-linge hublot SIEMENS WM16XLH2FF',
#   'note': 'no review',
#   'prix': '1299€00',
#   'image': 'https://tinyurl.com/2arbajq3'},
#  {'nom': 'Lave-linge hublot BOSCH WAN28117FF',
#   'note': 'no review',
#   'prix': '553€00',
#   'image': 'https://tinyurl.com/2yrmjsmj'},
#  {'nom': 'Lave-linge hublot SHARP ESNFA0142WD',
#   'note': '5/5 (1 avis clients)',
#   'prix': '456€00',
#   'image': 'https://tinyurl.com/2639quck'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W8W846WBFR',
#   'note': 'no review',
#   'prix': '679€99',
#   'image': 'https://tinyurl.com/2c5gf7zy'},
#  {'nom': 'Lave-linge hublot VEDETTE LFV184W',
#   'note': 'no review',
#   'prix': '453€00',
#   'image': 'https://tinyurl.com/26wxlue3'},
#  {'nom': 'Lave-linge top VEDETTE VT16022',
#   'note': 'no review',
#   'prix': '478€00',
#   'image': 'https://tinyurl.com/2y8cwj9p'},
#  {'nom': 'Lave-linge top CANDY CSTG482DE147',
#   'note': '5/5 (1 avis clients)',
#   'prix': '378€00',
#   'image': 'https://tinyurl.com/2xpvmvja'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4130SP',
#   'note': 'no review',
#   'prix': '549€99',
#   'image': 'https://tinyurl.com/2y387ccv'},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW7F3921RB',
#   'note': 'no review',
#   'prix': '759€99',
#   'image': 'https://tinyurl.com/25hsgb4p'},
#  {'nom': 'Lave-linge séchant ELECTROLUX EW7W3922RB',
#   'note': '5/5 (1 avis clients)',
#   'prix': '799€99',
#   'image': 'https://tinyurl.com/26wsvkj2'},
#  {'nom': 'Lave-linge hublot FAURE FWF84404DD',
#   'note': 'no review',
#   'prix': '486€00',
#   'image': 'https://tinyurl.com/25eeahht'},
#  {'nom': 'Lave-linge frontal SHARP ESHFB7143WD',
#   'note': 'no review',
#   'prix': '329€99',
#   'image': 'https://tinyurl.com/2xqqwlo9'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F3112RC',
#   'note': 'no review',
#   'prix': '634€00',
#   'image': 'https://tinyurl.com/263nvpf3'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W6W845WBFR',
#   'note': 'no review',
#   'prix': '738€00',
#   'image': 'https://tinyurl.com/2c59cqgq'},
#  {'nom': 'Lave-linge frontal LG F94V40WH',
#   'note': 'no review',
#   'prix': '564€00',
#   'image': 'https://tinyurl.com/23vbg3uc'},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW6F1495FC',
#   'note': 'no review',
#   'prix': '619€00',
#   'image': 'https://tinyurl.com/23og4gnk'},
#  {'nom': 'Lave-linge hublot FAURE FWF7474B52',
#   'note': 'no review',
#   'prix': '459€00',
#   'image': 'https://tinyurl.com/26jqfm99'},
#  {'nom': 'Lave-linge top BRANDT BT16524Q',
#   'note': 'no review',
#   'prix': '499€00',
#   'image': 'https://tinyurl.com/2btneqx3'},
#  {'nom': 'Lave-linge hublot BEKO WTV8712BS1W',
#   'note': 'no review',
#   'prix': '414€00',
#   'image': 'https://tinyurl.com/25vc44hy'},
#  {'nom': 'Lave-linge hublot BEKO LLF11W2',
#   'note': 'no review',
#   'prix': '531€00',
#   'image': 'https://tinyurl.com/22oym4rq'},
#  {'nom': 'Lave-linge hublot BOSCH WUU28T19FF',
#   'note': '5/5 (1 avis clients)',
#   'prix': '616€00',
#   'image': 'https://tinyurl.com/26x2nhqw'},
#  {'nom': 'Lave-linge séchant ELECTROLUX EWW1686WS',
#   'note': 'no review',
#   'prix': '724€00',
#   'image': 'https://tinyurl.com/24el2epq'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBD10469BSVFR',
#   'note': 'no review',
#   'prix': '653€00',
#   'image': 'https://tinyurl.com/27cvezss'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4805CR',
#   'note': 'no review',
#   'prix': '519€00',
#   'image': 'https://tinyurl.com/22nkh9pa'},
#  {'nom': 'Lave-linge hublot SHARP ESNFB914AWB',
#   'note': '5/5 (2 avis clients)',
#   'prix': '450€00',
#   'image': 'https://tinyurl.com/2dyshgn8'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBS8469WVFR',
#   'note': 'no review',
#   'prix': '528€00',
#   'image': 'https://tinyurl.com/29rz2hyx'},
#  {'nom': 'Lave-linge hublot BOSCH WAX32M01FF',
#   'note': 'no review',
#   'prix': '999€00',
#   'image': 'https://tinyurl.com/227auvtt'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T4020EH',
#   'note': 'no review',
#   'prix': '517€00',
#   'image': 'https://tinyurl.com/2356h7aq'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW11BB504DAWS3',
#   'note': 'no review',
#   'prix': '848€00',
#   'image': 'https://tinyurl.com/23ppjyv2'},
#  {'nom': 'Lave-linge frontal LG F14V52IXS',
#   'note': 'no review',
#   'prix': '705€00',
#   'image': 'https://tinyurl.com/2bknbudu'},
#  {'nom': 'Lave-linge top INDESIT BTWPS62400FRN',
#   'note': 'no review',
#   'prix': '399€99',
#   'image': 'https://tinyurl.com/25u2mj9j'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW11BB704DGWS3',
#   'note': '5/5 (1 avis clients)',
#   'prix': '793€00',
#   'image': 'https://tinyurl.com/25nhv3l6'},
#  {'nom': 'Lave-linge hublot MIELE WSA023',
#   'note': 'no review',
#   'prix': '949€99',
#   'image': 'https://tinyurl.com/2bxeu7cx'},
#  {'nom': 'Lave-linge hublot MIELE WCD660',
#   'note': 'no review',
#   'prix': '1393€00',
#   'image': 'https://tinyurl.com/28oxyg3m'},
#  {'nom': 'Lave-linge hublot BEKO WUE6612W1W',
#   'note': 'no review',
#   'prix': '337€00',
#   'image': 'https://tinyurl.com/2b5jme8r'}]

# %%
dataem2 #change price, translate note
# Out:
# [{'nom': 'Package LG 4.5 Cu. Ft. High',
#   'image': 'https://tinyurl.com/24lvt6d2',
#   'prix': '$1,299.98',
#   'note': 'User rating, 4.5 out of 5 stars with 1674 reviews.',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Ninja 7 Style Espresso & Coffee',
#   'image': 'https://tinyurl.com/22qzar3k',
#   'prix': '$199.99',
#   'note': 'Rating 4.6 out of 5 stars with 300 reviews',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'KingHome 150 Sq. Ft. 5,000 BTU',
#   'image': 'https://tinyurl.com/2dgqes54',
#   'prix': '$189.99',
#   'note': 'Rating 4 out of 5 stars with 2 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'LG 30" Built-In Electric Convection Combination',
#   'image': 'https://tinyurl.com/2cklfxy5',
#   'prix': '$2,999.99',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'BISSELL CrossWave Pet Pro All-in-One Multi-Surface',
#   'image': 'https://tinyurl.com/2dlv72yv',
#   'prix': '$329.59',
#   'note': 'Rating 4.3 out of 5 stars with 1251 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Package Thermador ProHarmony 5.0 Cu. Ft.',
#   'image': 'https://tinyurl.com/2asbf9q7',
#   'prix': '$11,998.00',
#   'note': 'User rating, 4.2 out of 5 stars with 29 reviews.',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Viking Professional 5 Series Quiet Cool',
#   'image': 'https://tinyurl.com/2yhhueo3',
#   'prix': '$11,259.00',
#   'note': 'Rating 4.3 out of 5 stars with 4 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Honeywell Home QuietSet Tower Fan White',
#   'image': 'https://tinyurl.com/28qk7stk',
#   'prix': '$61.99',
#   'note': 'Rating 4.4 out of 5 stars with 4135 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'LG 27 Cu. Ft. Side-by-Side Smart',
#   'image': 'https://tinyurl.com/22d8pepj',
#   'prix': '$1,699.99',
#   'note': 'Rating 4.6 out of 5 stars with 514 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Samsung 28 cu. ft. Side-by-Side Refrigerator',
#   'image': 'https://tinyurl.com/23hwnad8',
#   'prix': '$1,099.99',
#   'note': 'Rating 4.7 out of 5 stars with 476 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Panasonic HomeCHEF .7 Cu. Ft. 7-in-1',
#   'image': 'https://tinyurl.com/2aw6pvfj',
#   'prix': '$499.99',
#   'note': 'Rating 4.1 out of 5 stars with 33 reviews',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Shark Matrix Self-Emptying Robot Vacuum with',
#   'image': 'https://tinyurl.com/24rsdcuo',
#   'prix': '$499.99',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Package Bosch 800 Series 20.5 Cu.',
#   'image': 'https://tinyurl.com/2885u9lp',
#   'prix': '$12,019.96',
#   'note': 'User rating, 4.6 out of 5 stars with 341 reviews.',
#   'location': "Patte d'oie, Dakar, Sénégal"}]

# %%
locations = []
for occur in dataem3[1000:1060]:
    locations.append(occur["location"])
    #print(occur)
locations
for i in range (len(dataem1)):
    dataem1[i]["location"] = locations[i]
dataem1 #change price
# Out:
# [{'nom': 'Lave-linge séchant CANDY CSWS485TWMRE47',
#   'note': '4,5/5 (2 avis clients)',
#   'prix': '466€00',
#   'image': 'https://tinyurl.com/2y7m3phv',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '581€00',
#   'image': 'https://tinyurl.com/25uxyylg',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90T634DHE',
#   'note': '3/5 (1 avis clients)',
#   'prix': '622€00',
#   'image': 'https://tinyurl.com/2xvxqksy',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '649€00',
#   'image': 'https://tinyurl.com/2yyeweeu',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T684DLH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '693€00',
#   'image': 'https://tinyurl.com/28yvbs3o',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge séchant SAMSUNG WD10T534DBW',
#   'note': '1/5 (1 avis clients)',
#   'prix': '899€00',
#   'image': 'https://tinyurl.com/22bamgwd',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80TA046TH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '545€00',
#   'image': 'https://tinyurl.com/2742pjmr',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F51P12WH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '1099€00',
#   'image': 'https://tinyurl.com/238aw28b',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal LG F14V50WHS',
#   'note': 'no review',
#   'prix': '635€00',
#   'image': 'https://tinyurl.com/2cgzkqsz',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot HAIER HW09CP1439N',
#   'note': 'no review',
#   'prix': '473€00',
#   'image': 'https://tinyurl.com/26durlkl',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90TA046AX',
#   'note': '3,3/5 (3 avis clients)',
#   'prix': '601€00',
#   'image': 'https://tinyurl.com/2xna5aga',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot CANDY CO12105TE1S',
#   'note': '3/5 (2 avis clients)',
#   'prix': '369€99',
#   'image': 'https://tinyurl.com/28qqt6fs',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top BRANDT BT652AT',
#   'note': 'no review',
#   'prix': '479€00',
#   'image': 'https://tinyurl.com/27qqzmmh',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top VEDETTE LTV652B2',
#   'note': 'no review',
#   'prix': '468€00',
#   'image': 'https://tinyurl.com/28avenmu',
#   'location': 'Guediawaye, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top VEDETTE VLT1255W2',
#   'note': 'no review',
#   'prix': '440€00',
#   'image': 'https://tinyurl.com/2bjwg3m3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot INDESIT EWC71252WFRN',
#   'note': 'no review',
#   'prix': '422€00',
#   'image': 'https://tinyurl.com/2dj4re3q',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GV',
#   'note': 'no review',
#   'prix': '1031€00',
#   'image': 'https://tinyurl.com/2bc8rqac',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GW',
#   'note': 'no review',
#   'prix': '1199€00',
#   'image': 'https://tinyurl.com/265qyg6e',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal CANDY CSS1413TWME147',
#   'note': '4/5 (1 avis clients)',
#   'prix': '546€00',
#   'image': 'https://tinyurl.com/2axmzafv',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot VEDETTE LFVQ104W',
#   'note': '5/5 (1 avis clients)',
#   'prix': '489€99',
#   'image': 'https://tinyurl.com/26s2mo3l',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant CANDY CSWS4128TWME47',
#   'note': 'no review',
#   'prix': '796€00',
#   'image': 'https://tinyurl.com/2b3mtpqm',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant CANDY CSWS4962DWE1S',
#   'note': 'no review',
#   'prix': '540€00',
#   'image': 'https://tinyurl.com/2xumaadl',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot INDESIT BWA101283XWFRN',
#   'note': '5/5 (1 avis clients)',
#   'prix': '399€99',
#   'image': 'https://tinyurl.com/2bq26zbw',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BRANDT WFB180W',
#   'note': 'no review',
#   'prix': '446€00',
#   'image': 'https://tinyurl.com/296aqdax',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BRANDT WFB124QW',
#   'note': '4/5 (1 avis clients)',
#   'prix': '548€00',
#   'image': 'https://tinyurl.com/2anu4q67',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SIEMENS WM16XLH2FF',
#   'note': 'no review',
#   'prix': '1299€00',
#   'image': 'https://tinyurl.com/2arbajq3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BOSCH WAN28117FF',
#   'note': 'no review',
#   'prix': '553€00',
#   'image': 'https://tinyurl.com/2yrmjsmj',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SHARP ESNFA0142WD',
#   'note': '5/5 (1 avis clients)',
#   'prix': '456€00',
#   'image': 'https://tinyurl.com/2639quck',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W8W846WBFR',
#   'note': 'no review',
#   'prix': '679€99',
#   'image': 'https://tinyurl.com/2c5gf7zy',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot VEDETTE LFV184W',
#   'note': 'no review',
#   'prix': '453€00',
#   'image': 'https://tinyurl.com/26wxlue3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge top VEDETTE VT16022',
#   'note': 'no review',
#   'prix': '478€00',
#   'image': 'https://tinyurl.com/2y8cwj9p',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top CANDY CSTG482DE147',
#   'note': '5/5 (1 avis clients)',
#   'prix': '378€00',
#   'image': 'https://tinyurl.com/2xpvmvja',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4130SP',
#   'note': 'no review',
#   'prix': '549€99',
#   'image': 'https://tinyurl.com/2y387ccv',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW7F3921RB',
#   'note': 'no review',
#   'prix': '759€99',
#   'image': 'https://tinyurl.com/25hsgb4p',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant ELECTROLUX EW7W3922RB',
#   'note': '5/5 (1 avis clients)',
#   'prix': '799€99',
#   'image': 'https://tinyurl.com/26wsvkj2',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot FAURE FWF84404DD',
#   'note': 'no review',
#   'prix': '486€00',
#   'image': 'https://tinyurl.com/25eeahht',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SHARP ESHFB7143WD',
#   'note': 'no review',
#   'prix': '329€99',
#   'image': 'https://tinyurl.com/2xqqwlo9',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F3112RC',
#   'note': 'no review',
#   'prix': '634€00',
#   'image': 'https://tinyurl.com/263nvpf3',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W6W845WBFR',
#   'note': 'no review',
#   'prix': '738€00',
#   'image': 'https://tinyurl.com/2c59cqgq',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F94V40WH',
#   'note': 'no review',
#   'prix': '564€00',
#   'image': 'https://tinyurl.com/23vbg3uc',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW6F1495FC',
#   'note': 'no review',
#   'prix': '619€00',
#   'image': 'https://tinyurl.com/23og4gnk',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot FAURE FWF7474B52',
#   'note': 'no review',
#   'prix': '459€00',
#   'image': 'https://tinyurl.com/26jqfm99',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top BRANDT BT16524Q',
#   'note': 'no review',
#   'prix': '499€00',
#   'image': 'https://tinyurl.com/2btneqx3',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BEKO WTV8712BS1W',
#   'note': 'no review',
#   'prix': '414€00',
#   'image': 'https://tinyurl.com/25vc44hy',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BEKO LLF11W2',
#   'note': 'no review',
#   'prix': '531€00',
#   'image': 'https://tinyurl.com/22oym4rq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BOSCH WUU28T19FF',
#   'note': '5/5 (1 avis clients)',
#   'prix': '616€00',
#   'image': 'https://tinyurl.com/26x2nhqw',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge séchant ELECTROLUX EWW1686WS',
#   'note': 'no review',
#   'prix': '724€00',
#   'image': 'https://tinyurl.com/24el2epq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBD10469BSVFR',
#   'note': 'no review',
#   'prix': '653€00',
#   'image': 'https://tinyurl.com/27cvezss',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4805CR',
#   'note': 'no review',
#   'prix': '519€00',
#   'image': 'https://tinyurl.com/22nkh9pa',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SHARP ESNFB914AWB',
#   'note': '5/5 (2 avis clients)',
#   'prix': '450€00',
#   'image': 'https://tinyurl.com/2dyshgn8',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBS8469WVFR',
#   'note': 'no review',
#   'prix': '528€00',
#   'image': 'https://tinyurl.com/29rz2hyx',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BOSCH WAX32M01FF',
#   'note': 'no review',
#   'prix': '999€00',
#   'image': 'https://tinyurl.com/227auvtt',
#   'location': 'Guediawaye, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T4020EH',
#   'note': 'no review',
#   'prix': '517€00',
#   'image': 'https://tinyurl.com/2356h7aq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW11BB504DAWS3',
#   'note': 'no review',
#   'prix': '848€00',
#   'image': 'https://tinyurl.com/23ppjyv2',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F14V52IXS',
#   'note': 'no review',
#   'prix': '705€00',
#   'image': 'https://tinyurl.com/2bknbudu',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top INDESIT BTWPS62400FRN',
#   'note': 'no review',
#   'prix': '399€99',
#   'image': 'https://tinyurl.com/25u2mj9j',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW11BB704DGWS3',
#   'note': '5/5 (1 avis clients)',
#   'prix': '793€00',
#   'image': 'https://tinyurl.com/25nhv3l6',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot MIELE WSA023',
#   'note': 'no review',
#   'prix': '949€99',
#   'image': 'https://tinyurl.com/2bxeu7cx',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot MIELE WCD660',
#   'note': 'no review',
#   'prix': '1393€00',
#   'image': 'https://tinyurl.com/28oxyg3m',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BEKO WUE6612W1W',
#   'note': 'no review',
#   'prix': '337€00',
#   'image': 'https://tinyurl.com/2b5jme8r',
#   'location': 'Almadies, Dakar, Sénégal'}]

# %%
# rm notes, convert price, 
from pprint import pprint as pp
tabprix = []
# Out:
# [{'image': 'https://tinyurl.com/2y7m3phv',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge séchant CANDY CSWS485TWMRE47',
#   'note': '4,5/5 (2 avis clients)',
#   'prix': '306781 CFA'},
#  {'image': 'https://tinyurl.com/25uxyylg',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SAMSUNG WW90T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '382489 CFA'},
#  {'image': 'https://tinyurl.com/2xvxqksy',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge frontal SAMSUNG WW90T634DHE',
#   'note': '3/5 (1 avis clients)',
#   'prix': '409481 CFA'},
#  {'image': 'https://tinyurl.com/2yyeweeu',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot SAMSUNG WW80T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '427256 CFA'},
#  {'image': 'https://tinyurl.com/28yvbs3o',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SAMSUNG WW80T684DLH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '456222 CFA'},
#  {'image': 'https://tinyurl.com/22bamgwd',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge séchant SAMSUNG WD10T534DBW',
#   'note': '1/5 (1 avis clients)',
#   'prix': '591838 CFA'},
#  {'image': 'https://tinyurl.com/2742pjmr',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SAMSUNG WW80TA046TH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '358789 CFA'},
#  {'image': 'https://tinyurl.com/238aw28b',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge frontal LG F51P12WH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '723504 CFA'},
#  {'image': 'https://tinyurl.com/2cgzkqsz',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal LG F14V50WHS',
#   'note': 'no review',
#   'prix': '418039 CFA'},
#  {'image': 'https://tinyurl.com/26durlkl',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot HAIER HW09CP1439N',
#   'note': 'no review',
#   'prix': '311390 CFA'},
#  {'image': 'https://tinyurl.com/2xna5aga',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal SAMSUNG WW90TA046AX',
#   'note': '3,3/5 (3 avis clients)',
#   'prix': '395656 CFA'},
#  {'image': 'https://tinyurl.com/28qqt6fs',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot CANDY CO12105TE1S',
#   'note': '3/5 (2 avis clients)',
#   'prix': '242923 CFA'},
#  {'image': 'https://tinyurl.com/27qqzmmh',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge top BRANDT BT652AT',
#   'note': 'no review',
#   'prix': '315340 CFA'},
#  {'image': 'https://tinyurl.com/28avenmu',
#   'location': 'Guediawaye, Dakar, Sénégal',
#   'nom': 'Lave-linge top VEDETTE LTV652B2',
#   'note': 'no review',
#   'prix': '308098 CFA'},
#  {'image': 'https://tinyurl.com/2bjwg3m3',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge top VEDETTE VLT1255W2',
#   'note': 'no review',
#   'prix': '289665 CFA'},
#  {'image': 'https://tinyurl.com/2dj4re3q',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot INDESIT EWC71252WFRN',
#   'note': 'no review',
#   'prix': '277815 CFA'},
#  {'image': 'https://tinyurl.com/2bc8rqac',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot SAMSUNG WF18T8000GV',
#   'note': 'no review',
#   'prix': '678738 CFA'},
#  {'image': 'https://tinyurl.com/265qyg6e',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot SAMSUNG WF18T8000GW',
#   'note': 'no review',
#   'prix': '789337 CFA'},
#  {'image': 'https://tinyurl.com/2axmzafv',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge frontal CANDY CSS1413TWME147',
#   'note': '4/5 (1 avis clients)',
#   'prix': '359448 CFA'},
#  {'image': 'https://tinyurl.com/26s2mo3l',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot VEDETTE LFVQ104W',
#   'note': '5/5 (1 avis clients)',
#   'prix': '321923 CFA'},
#  {'image': 'https://tinyurl.com/2b3mtpqm',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge séchant CANDY CSWS4128TWME47',
#   'note': 'no review',
#   'prix': '524030 CFA'},
#  {'image': 'https://tinyurl.com/2xumaadl',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge séchant CANDY CSWS4962DWE1S',
#   'note': 'no review',
#   'prix': '355498 CFA'},
#  {'image': 'https://tinyurl.com/2bq26zbw',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot INDESIT BWA101283XWFRN',
#   'note': '5/5 (1 avis clients)',
#   'prix': '262673 CFA'},
#  {'image': 'https://tinyurl.com/296aqdax',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot BRANDT WFB180W',
#   'note': 'no review',
#   'prix': '293615 CFA'},
#  {'image': 'https://tinyurl.com/2anu4q67',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot BRANDT WFB124QW',
#   'note': '4/5 (1 avis clients)',
#   'prix': '360764 CFA'},
#  {'image': 'https://tinyurl.com/2arbajq3',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot SIEMENS WM16XLH2FF',
#   'note': 'no review',
#   'prix': '855170 CFA'},
#  {'image': 'https://tinyurl.com/2yrmjsmj',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BOSCH WAN28117FF',
#   'note': 'no review',
#   'prix': '364056 CFA'},
#  {'image': 'https://tinyurl.com/2639quck',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SHARP ESNFA0142WD',
#   'note': '5/5 (1 avis clients)',
#   'prix': '300198 CFA'},
#  {'image': 'https://tinyurl.com/2c5gf7zy',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot WHIRLPOOL W8W846WBFR',
#   'note': 'no review',
#   'prix': '447006 CFA'},
#  {'image': 'https://tinyurl.com/26wxlue3',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot VEDETTE LFV184W',
#   'note': 'no review',
#   'prix': '298223 CFA'},
#  {'image': 'https://tinyurl.com/2y8cwj9p',
#   'location': 'Grand Yoff, Dakar, Sénégal',
#   'nom': 'Lave-linge top VEDETTE VT16022',
#   'note': 'no review',
#   'prix': '314681 CFA'},
#  {'image': 'https://tinyurl.com/2xpvmvja',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge top CANDY CSTG482DE147',
#   'note': '5/5 (1 avis clients)',
#   'prix': '248848 CFA'},
#  {'image': 'https://tinyurl.com/2y387ccv',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal ELECTROLUX EW6F4130SP',
#   'note': 'no review',
#   'prix': '361423 CFA'},
#  {'image': 'https://tinyurl.com/25hsgb4p',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot ELECTROLUX EW7F3921RB',
#   'note': 'no review',
#   'prix': '499672 CFA'},
#  {'image': 'https://tinyurl.com/26wsvkj2',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge séchant ELECTROLUX EW7W3922RB',
#   'note': '5/5 (1 avis clients)',
#   'prix': '526005 CFA'},
#  {'image': 'https://tinyurl.com/25eeahht',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot FAURE FWF84404DD',
#   'note': 'no review',
#   'prix': '319948 CFA'},
#  {'image': 'https://tinyurl.com/2xqqwlo9',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal SHARP ESHFB7143WD',
#   'note': 'no review',
#   'prix': '216590 CFA'},
#  {'image': 'https://tinyurl.com/263nvpf3',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal ELECTROLUX EW6F3112RC',
#   'note': 'no review',
#   'prix': '417381 CFA'},
#  {'image': 'https://tinyurl.com/2c59cqgq',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot WHIRLPOOL W6W845WBFR',
#   'note': 'no review',
#   'prix': '485847 CFA'},
#  {'image': 'https://tinyurl.com/23vbg3uc',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge frontal LG F94V40WH',
#   'note': 'no review',
#   'prix': '371298 CFA'},
#  {'image': 'https://tinyurl.com/23og4gnk',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot ELECTROLUX EW6F1495FC',
#   'note': 'no review',
#   'prix': '407506 CFA'},
#  {'image': 'https://tinyurl.com/26jqfm99',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot FAURE FWF7474B52',
#   'note': 'no review',
#   'prix': '302173 CFA'},
#  {'image': 'https://tinyurl.com/2btneqx3',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge top BRANDT BT16524Q',
#   'note': 'no review',
#   'prix': '328506 CFA'},
#  {'image': 'https://tinyurl.com/25vc44hy',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BEKO WTV8712BS1W',
#   'note': 'no review',
#   'prix': '272548 CFA'},
#  {'image': 'https://tinyurl.com/22oym4rq',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BEKO LLF11W2',
#   'note': 'no review',
#   'prix': '349573 CFA'},
#  {'image': 'https://tinyurl.com/26x2nhqw',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BOSCH WUU28T19FF',
#   'note': '5/5 (1 avis clients)',
#   'prix': '405531 CFA'},
#  {'image': 'https://tinyurl.com/24el2epq',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge séchant ELECTROLUX EWW1686WS',
#   'note': 'no review',
#   'prix': '476630 CFA'},
#  {'image': 'https://tinyurl.com/27cvezss',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot WHIRLPOOL FFBD10469BSVFR',
#   'note': 'no review',
#   'prix': '429889 CFA'},
#  {'image': 'https://tinyurl.com/22nkh9pa',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge frontal ELECTROLUX EW6F4805CR',
#   'note': 'no review',
#   'prix': '341673 CFA'},
#  {'image': 'https://tinyurl.com/2dyshgn8',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SHARP ESNFB914AWB',
#   'note': '5/5 (2 avis clients)',
#   'prix': '296248 CFA'},
#  {'image': 'https://tinyurl.com/29rz2hyx',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot WHIRLPOOL FFBS8469WVFR',
#   'note': 'no review',
#   'prix': '347598 CFA'},
#  {'image': 'https://tinyurl.com/227auvtt',
#   'location': 'Guediawaye, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BOSCH WAX32M01FF',
#   'note': 'no review',
#   'prix': '657671 CFA'},
#  {'image': 'https://tinyurl.com/2356h7aq',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SAMSUNG WW90T4020EH',
#   'note': 'no review',
#   'prix': '340356 CFA'},
#  {'image': 'https://tinyurl.com/23ppjyv2',
#   'location': 'Grand Yoff, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal SAMSUNG WW11BB504DAWS3',
#   'note': 'no review',
#   'prix': '558263 CFA'},
#  {'image': 'https://tinyurl.com/2bknbudu',
#   'location': 'Grand Yoff, Dakar, Sénégal',
#   'nom': 'Lave-linge frontal LG F14V52IXS',
#   'note': 'no review',
#   'prix': '464122 CFA'},
#  {'image': 'https://tinyurl.com/25u2mj9j',
#   'location': 'Grand Yoff, Dakar, Sénégal',
#   'nom': 'Lave-linge top INDESIT BTWPS62400FRN',
#   'note': 'no review',
#   'prix': '262673 CFA'},
#  {'image': 'https://tinyurl.com/25nhv3l6',
#   'location': 'Grand Yoff, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot SAMSUNG WW11BB704DGWS3',
#   'note': '5/5 (1 avis clients)',
#   'prix': '522055 CFA'},
#  {'image': 'https://tinyurl.com/2bxeu7cx',
#   'location': 'Dakar, Sénégal',
#   'nom': 'Lave-linge hublot MIELE WSA023',
#   'note': 'no review',
#   'prix': '624755 CFA'},
#  {'image': 'https://tinyurl.com/28oxyg3m',
#   'location': "Patte d'oie, Dakar, Sénégal",
#   'nom': 'Lave-linge hublot MIELE WCD660',
#   'note': 'no review',
#   'prix': '917053 CFA'},
#  {'image': 'https://tinyurl.com/2b5jme8r',
#   'location': 'Almadies, Dakar, Sénégal',
#   'nom': 'Lave-linge hublot BEKO WUE6612W1W',
#   'note': 'no review',
#   'prix': '221857 CFA'}]

# %%
# Out:
# ['785895 CFA',
#  '120395 CFA',
#  '114345 CFA',
#  '1814395 CFA',
#  '199045 CFA',
#  '7258790 CFA',
#  '6811695 CFA',
#  '36905 CFA',
#  '1027895 CFA',
#  '664895 CFA',
#  '301895 CFA',
#  '301895 CFA',
#  '7271495 CFA']

# %%
#dataem2


dataem2
# Out:
# [{'nom': 'Package LG 4.5 Cu. Ft. High',
#   'image': 'https://tinyurl.com/24lvt6d2',
#   'prix': '785895 CFA',
#   'note': 'User rating, 4.5 out of 5 stars with 1674 reviews.',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Ninja 7 Style Espresso & Coffee',
#   'image': 'https://tinyurl.com/22qzar3k',
#   'prix': '120395 CFA',
#   'note': 'Rating 4.6 out of 5 stars with 300 reviews',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'KingHome 150 Sq. Ft. 5,000 BTU',
#   'image': 'https://tinyurl.com/2dgqes54',
#   'prix': '114345 CFA',
#   'note': 'Rating 4 out of 5 stars with 2 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'LG 30" Built-In Electric Convection Combination',
#   'image': 'https://tinyurl.com/2cklfxy5',
#   'prix': '1814395 CFA',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'BISSELL CrossWave Pet Pro All-in-One Multi-Surface',
#   'image': 'https://tinyurl.com/2dlv72yv',
#   'prix': '199045 CFA',
#   'note': 'Rating 4.3 out of 5 stars with 1251 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Package Thermador ProHarmony 5.0 Cu. Ft.',
#   'image': 'https://tinyurl.com/2asbf9q7',
#   'prix': '7258790 CFA',
#   'note': 'User rating, 4.2 out of 5 stars with 29 reviews.',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Viking Professional 5 Series Quiet Cool',
#   'image': 'https://tinyurl.com/2yhhueo3',
#   'prix': '6811695 CFA',
#   'note': 'Rating 4.3 out of 5 stars with 4 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Honeywell Home QuietSet Tower Fan White',
#   'image': 'https://tinyurl.com/28qk7stk',
#   'prix': '36905 CFA',
#   'note': 'Rating 4.4 out of 5 stars with 4135 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'LG 27 Cu. Ft. Side-by-Side Smart',
#   'image': 'https://tinyurl.com/22d8pepj',
#   'prix': '1027895 CFA',
#   'note': 'Rating 4.6 out of 5 stars with 514 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Samsung 28 cu. ft. Side-by-Side Refrigerator',
#   'image': 'https://tinyurl.com/23hwnad8',
#   'prix': '664895 CFA',
#   'note': 'Rating 4.7 out of 5 stars with 476 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Panasonic HomeCHEF .7 Cu. Ft. 7-in-1',
#   'image': 'https://tinyurl.com/2aw6pvfj',
#   'prix': '301895 CFA',
#   'note': 'Rating 4.1 out of 5 stars with 33 reviews',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Shark Matrix Self-Emptying Robot Vacuum with',
#   'image': 'https://tinyurl.com/24rsdcuo',
#   'prix': '301895 CFA',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Package Bosch 800 Series 20.5 Cu.',
#   'image': 'https://tinyurl.com/2885u9lp',
#   'prix': '7271495 CFA',
#   'note': 'User rating, 4.6 out of 5 stars with 341 reviews.',
#   'location': "Patte d'oie, Dakar, Sénégal"}]

# %%
len(dataem1et2)
# Out:
# 73

# %%
    pp(cd)
# Out:
# {'image': 'https://tinyurl.com/2y7m3phv',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge séchant CANDY CSWS485TWMRE47',
#  'prix': '306781 CFA'}
# {'image': 'https://tinyurl.com/25uxyylg',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SAMSUNG WW90T554DTW',
#  'prix': '382489 CFA'}
# {'image': 'https://tinyurl.com/2xvxqksy',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge frontal SAMSUNG WW90T634DHE',
#  'prix': '409481 CFA'}
# {'image': 'https://tinyurl.com/2yyeweeu',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot SAMSUNG WW80T554DTW',
#  'prix': '427256 CFA'}
# {'image': 'https://tinyurl.com/28yvbs3o',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SAMSUNG WW80T684DLH',
#  'prix': '456222 CFA'}
# {'image': 'https://tinyurl.com/22bamgwd',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge séchant SAMSUNG WD10T534DBW',
#  'prix': '591838 CFA'}
# {'image': 'https://tinyurl.com/2742pjmr',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SAMSUNG WW80TA046TH',
#  'prix': '358789 CFA'}
# {'image': 'https://tinyurl.com/238aw28b',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge frontal LG F51P12WH',
#  'prix': '723504 CFA'}
# {'image': 'https://tinyurl.com/2cgzkqsz',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal LG F14V50WHS',
#  'prix': '418039 CFA'}
# {'image': 'https://tinyurl.com/26durlkl',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot HAIER HW09CP1439N',
#  'prix': '311390 CFA'}
# {'image': 'https://tinyurl.com/2xna5aga',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal SAMSUNG WW90TA046AX',
#  'prix': '395656 CFA'}
# {'image': 'https://tinyurl.com/28qqt6fs',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot CANDY CO12105TE1S',
#  'prix': '242923 CFA'}
# {'image': 'https://tinyurl.com/27qqzmmh',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge top BRANDT BT652AT',
#  'prix': '315340 CFA'}
# {'image': 'https://tinyurl.com/28avenmu',
#  'location': 'Guediawaye, Dakar, Sénégal',
#  'nom': 'Lave-linge top VEDETTE LTV652B2',
#  'prix': '308098 CFA'}
# {'image': 'https://tinyurl.com/2bjwg3m3',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge top VEDETTE VLT1255W2',
#  'prix': '289665 CFA'}
# {'image': 'https://tinyurl.com/2dj4re3q',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot INDESIT EWC71252WFRN',
#  'prix': '277815 CFA'}
# {'image': 'https://tinyurl.com/2bc8rqac',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot SAMSUNG WF18T8000GV',
#  'prix': '678738 CFA'}
# {'image': 'https://tinyurl.com/265qyg6e',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot SAMSUNG WF18T8000GW',
#  'prix': '789337 CFA'}
# {'image': 'https://tinyurl.com/2axmzafv',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge frontal CANDY CSS1413TWME147',
#  'prix': '359448 CFA'}
# {'image': 'https://tinyurl.com/26s2mo3l',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot VEDETTE LFVQ104W',
#  'prix': '321923 CFA'}
# {'image': 'https://tinyurl.com/2b3mtpqm',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge séchant CANDY CSWS4128TWME47',
#  'prix': '524030 CFA'}
# {'image': 'https://tinyurl.com/2xumaadl',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge séchant CANDY CSWS4962DWE1S',
#  'prix': '355498 CFA'}
# {'image': 'https://tinyurl.com/2bq26zbw',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot INDESIT BWA101283XWFRN',
#  'prix': '262673 CFA'}
# {'image': 'https://tinyurl.com/296aqdax',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot BRANDT WFB180W',
#  'prix': '293615 CFA'}
# {'image': 'https://tinyurl.com/2anu4q67',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot BRANDT WFB124QW',
#  'prix': '360764 CFA'}
# {'image': 'https://tinyurl.com/2arbajq3',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot SIEMENS WM16XLH2FF',
#  'prix': '855170 CFA'}
# {'image': 'https://tinyurl.com/2yrmjsmj',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BOSCH WAN28117FF',
#  'prix': '364056 CFA'}
# {'image': 'https://tinyurl.com/2639quck',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SHARP ESNFA0142WD',
#  'prix': '300198 CFA'}
# {'image': 'https://tinyurl.com/2c5gf7zy',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot WHIRLPOOL W8W846WBFR',
#  'prix': '447006 CFA'}
# {'image': 'https://tinyurl.com/26wxlue3',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot VEDETTE LFV184W',
#  'prix': '298223 CFA'}
# {'image': 'https://tinyurl.com/2y8cwj9p',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Lave-linge top VEDETTE VT16022',
#  'prix': '314681 CFA'}
# {'image': 'https://tinyurl.com/2xpvmvja',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge top CANDY CSTG482DE147',
#  'prix': '248848 CFA'}
# {'image': 'https://tinyurl.com/2y387ccv',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal ELECTROLUX EW6F4130SP',
#  'prix': '361423 CFA'}
# {'image': 'https://tinyurl.com/25hsgb4p',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot ELECTROLUX EW7F3921RB',
#  'prix': '499672 CFA'}
# {'image': 'https://tinyurl.com/26wsvkj2',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge séchant ELECTROLUX EW7W3922RB',
#  'prix': '526005 CFA'}
# {'image': 'https://tinyurl.com/25eeahht',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot FAURE FWF84404DD',
#  'prix': '319948 CFA'}
# {'image': 'https://tinyurl.com/2xqqwlo9',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal SHARP ESHFB7143WD',
#  'prix': '216590 CFA'}
# {'image': 'https://tinyurl.com/263nvpf3',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal ELECTROLUX EW6F3112RC',
#  'prix': '417381 CFA'}
# {'image': 'https://tinyurl.com/2c59cqgq',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot WHIRLPOOL W6W845WBFR',
#  'prix': '485847 CFA'}
# {'image': 'https://tinyurl.com/23vbg3uc',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge frontal LG F94V40WH',
#  'prix': '371298 CFA'}
# {'image': 'https://tinyurl.com/23og4gnk',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot ELECTROLUX EW6F1495FC',
#  'prix': '407506 CFA'}
# {'image': 'https://tinyurl.com/26jqfm99',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot FAURE FWF7474B52',
#  'prix': '302173 CFA'}
# {'image': 'https://tinyurl.com/2btneqx3',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge top BRANDT BT16524Q',
#  'prix': '328506 CFA'}
# {'image': 'https://tinyurl.com/25vc44hy',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BEKO WTV8712BS1W',
#  'prix': '272548 CFA'}
# {'image': 'https://tinyurl.com/22oym4rq',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BEKO LLF11W2',
#  'prix': '349573 CFA'}
# {'image': 'https://tinyurl.com/26x2nhqw',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BOSCH WUU28T19FF',
#  'prix': '405531 CFA'}
# {'image': 'https://tinyurl.com/24el2epq',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge séchant ELECTROLUX EWW1686WS',
#  'prix': '476630 CFA'}
# {'image': 'https://tinyurl.com/27cvezss',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot WHIRLPOOL FFBD10469BSVFR',
#  'prix': '429889 CFA'}
# {'image': 'https://tinyurl.com/22nkh9pa',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge frontal ELECTROLUX EW6F4805CR',
#  'prix': '341673 CFA'}
# {'image': 'https://tinyurl.com/2dyshgn8',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SHARP ESNFB914AWB',
#  'prix': '296248 CFA'}
# {'image': 'https://tinyurl.com/29rz2hyx',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot WHIRLPOOL FFBS8469WVFR',
#  'prix': '347598 CFA'}
# {'image': 'https://tinyurl.com/227auvtt',
#  'location': 'Guediawaye, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BOSCH WAX32M01FF',
#  'prix': '657671 CFA'}
# {'image': 'https://tinyurl.com/2356h7aq',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SAMSUNG WW90T4020EH',
#  'prix': '340356 CFA'}
# {'image': 'https://tinyurl.com/23ppjyv2',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal SAMSUNG WW11BB504DAWS3',
#  'prix': '558263 CFA'}
# {'image': 'https://tinyurl.com/2bknbudu',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Lave-linge frontal LG F14V52IXS',
#  'prix': '464122 CFA'}
# {'image': 'https://tinyurl.com/25u2mj9j',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Lave-linge top INDESIT BTWPS62400FRN',
#  'prix': '262673 CFA'}
# {'image': 'https://tinyurl.com/25nhv3l6',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot SAMSUNG WW11BB704DGWS3',
#  'prix': '522055 CFA'}
# {'image': 'https://tinyurl.com/2bxeu7cx',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Lave-linge hublot MIELE WSA023',
#  'prix': '624755 CFA'}
# {'image': 'https://tinyurl.com/28oxyg3m',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Lave-linge hublot MIELE WCD660',
#  'prix': '917053 CFA'}
# {'image': 'https://tinyurl.com/2b5jme8r',
#  'location': 'Almadies, Dakar, Sénégal',
#  'nom': 'Lave-linge hublot BEKO WUE6612W1W',
#  'prix': '221857 CFA'}
# {'image': 'https://tinyurl.com/24lvt6d2',
#  'location': 'Dakar, Sénégal',
#  'nom': 'Package LG 4.5 Cu. Ft. High',
#  'prix': '785895 CFA'}
# {'image': 'https://tinyurl.com/22qzar3k',
#  'location': 'Dakar Plateau, Dakar, Sénégal',
#  'nom': 'Ninja 7 Style Espresso & Coffee',
#  'prix': '120395 CFA'}
# {'image': 'https://tinyurl.com/2dgqes54',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'KingHome 150 Sq. Ft. 5,000 BTU',
#  'prix': '114345 CFA'}
# {'image': 'https://tinyurl.com/2cklfxy5',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'LG 30" Built-In Electric Convection Combination',
#  'prix': '1814395 CFA'}
# {'image': 'https://tinyurl.com/2dlv72yv',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'BISSELL CrossWave Pet Pro All-in-One Multi-Surface',
#  'prix': '199045 CFA'}
# {'image': 'https://tinyurl.com/2asbf9q7',
#  'location': 'Grand Yoff, Dakar, Sénégal',
#  'nom': 'Package Thermador ProHarmony 5.0 Cu. Ft.',
#  'prix': '7258790 CFA'}
# {'image': 'https://tinyurl.com/2yhhueo3',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Viking Professional 5 Series Quiet Cool',
#  'prix': '6811695 CFA'}
# {'image': 'https://tinyurl.com/28qk7stk',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Honeywell Home QuietSet Tower Fan White',
#  'prix': '36905 CFA'}
# {'image': 'https://tinyurl.com/22d8pepj',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'LG 27 Cu. Ft. Side-by-Side Smart',
#  'prix': '1027895 CFA'}
# {'image': 'https://tinyurl.com/23hwnad8',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Samsung 28 cu. ft. Side-by-Side Refrigerator',
#  'prix': '664895 CFA'}
# {'image': 'https://tinyurl.com/2aw6pvfj',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Panasonic HomeCHEF .7 Cu. Ft. 7-in-1',
#  'prix': '301895 CFA'}
# {'image': 'https://tinyurl.com/24rsdcuo',
#  'location': 'Ouakam, Dakar, Sénégal',
#  'nom': 'Shark Matrix Self-Emptying Robot Vacuum with',
#  'prix': '301895 CFA'}
# {'image': 'https://tinyurl.com/2885u9lp',
#  'location': "Patte d'oie, Dakar, Sénégal",
#  'nom': 'Package Bosch 800 Series 20.5 Cu.',
#  'prix': '7271495 CFA'}

# %%
# Out:
# [{'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'}]

# %%
len(data)

# %%
data
# Out:
# [{'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'image': 'https://tinyurl.com/2a2kdlpf',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Cuisinière Astech 5 feux',
#   'prix': '285000 CFA'},
#  {'image': 'https://tinyurl.com/2xrcou58',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Congelateur Astech 400L A+',
#   'prix': '219900 CFA'},
#  {'image': 'https://tinyurl.com/22xr962s',
#   'location': 'Dakar Plateau, Dakar, Sénégal',
#   'nom': 'Climatiseur portatif Roch 12000 btu',
#   'prix': '210000 CFA'},
#  {'image': 'https://tinyurl.com/2cjpunch',
#   'location': 'Ouakam, Dakar, Sénégal',
#   'nom': 'Cuisiniére électrique Astech 4 feux 60*60',
#   'prix': '229900 CFA'},
#  {'nom': 'Lave-linge séchant CANDY CSWS485TWMRE47',
#   'note': '4,5/5 (2 avis clients)',
#   'prix': '306781 CFA',
#   'image': 'https://tinyurl.com/2y7m3phv',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '382489 CFA',
#   'image': 'https://tinyurl.com/25uxyylg',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90T634DHE',
#   'note': '3/5 (1 avis clients)',
#   'prix': '409481 CFA',
#   'image': 'https://tinyurl.com/2xvxqksy',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T554DTW',
#   'note': '5/5 (1 avis clients)',
#   'prix': '427256 CFA',
#   'image': 'https://tinyurl.com/2yyeweeu',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80T684DLH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '456222 CFA',
#   'image': 'https://tinyurl.com/28yvbs3o',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge séchant SAMSUNG WD10T534DBW',
#   'note': '1/5 (1 avis clients)',
#   'prix': '591838 CFA',
#   'image': 'https://tinyurl.com/22bamgwd',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WW80TA046TH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '358789 CFA',
#   'image': 'https://tinyurl.com/2742pjmr',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F51P12WH',
#   'note': '5/5 (1 avis clients)',
#   'prix': '723504 CFA',
#   'image': 'https://tinyurl.com/238aw28b',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal LG F14V50WHS',
#   'note': 'no review',
#   'prix': '418039 CFA',
#   'image': 'https://tinyurl.com/2cgzkqsz',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot HAIER HW09CP1439N',
#   'note': 'no review',
#   'prix': '311390 CFA',
#   'image': 'https://tinyurl.com/26durlkl',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW90TA046AX',
#   'note': '3,3/5 (3 avis clients)',
#   'prix': '395656 CFA',
#   'image': 'https://tinyurl.com/2xna5aga',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot CANDY CO12105TE1S',
#   'note': '3/5 (2 avis clients)',
#   'prix': '242923 CFA',
#   'image': 'https://tinyurl.com/28qqt6fs',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top BRANDT BT652AT',
#   'note': 'no review',
#   'prix': '315340 CFA',
#   'image': 'https://tinyurl.com/27qqzmmh',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top VEDETTE LTV652B2',
#   'note': 'no review',
#   'prix': '308098 CFA',
#   'image': 'https://tinyurl.com/28avenmu',
#   'location': 'Guediawaye, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top VEDETTE VLT1255W2',
#   'note': 'no review',
#   'prix': '289665 CFA',
#   'image': 'https://tinyurl.com/2bjwg3m3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot INDESIT EWC71252WFRN',
#   'note': 'no review',
#   'prix': '277815 CFA',
#   'image': 'https://tinyurl.com/2dj4re3q',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GV',
#   'note': 'no review',
#   'prix': '678738 CFA',
#   'image': 'https://tinyurl.com/2bc8rqac',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SAMSUNG WF18T8000GW',
#   'note': 'no review',
#   'prix': '789337 CFA',
#   'image': 'https://tinyurl.com/265qyg6e',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal CANDY CSS1413TWME147',
#   'note': '4/5 (1 avis clients)',
#   'prix': '359448 CFA',
#   'image': 'https://tinyurl.com/2axmzafv',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot VEDETTE LFVQ104W',
#   'note': '5/5 (1 avis clients)',
#   'prix': '321923 CFA',
#   'image': 'https://tinyurl.com/26s2mo3l',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant CANDY CSWS4128TWME47',
#   'note': 'no review',
#   'prix': '524030 CFA',
#   'image': 'https://tinyurl.com/2b3mtpqm',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant CANDY CSWS4962DWE1S',
#   'note': 'no review',
#   'prix': '355498 CFA',
#   'image': 'https://tinyurl.com/2xumaadl',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot INDESIT BWA101283XWFRN',
#   'note': '5/5 (1 avis clients)',
#   'prix': '262673 CFA',
#   'image': 'https://tinyurl.com/2bq26zbw',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BRANDT WFB180W',
#   'note': 'no review',
#   'prix': '293615 CFA',
#   'image': 'https://tinyurl.com/296aqdax',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BRANDT WFB124QW',
#   'note': '4/5 (1 avis clients)',
#   'prix': '360764 CFA',
#   'image': 'https://tinyurl.com/2anu4q67',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SIEMENS WM16XLH2FF',
#   'note': 'no review',
#   'prix': '855170 CFA',
#   'image': 'https://tinyurl.com/2arbajq3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BOSCH WAN28117FF',
#   'note': 'no review',
#   'prix': '364056 CFA',
#   'image': 'https://tinyurl.com/2yrmjsmj',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SHARP ESNFA0142WD',
#   'note': '5/5 (1 avis clients)',
#   'prix': '300198 CFA',
#   'image': 'https://tinyurl.com/2639quck',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W8W846WBFR',
#   'note': 'no review',
#   'prix': '447006 CFA',
#   'image': 'https://tinyurl.com/2c5gf7zy',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot VEDETTE LFV184W',
#   'note': 'no review',
#   'prix': '298223 CFA',
#   'image': 'https://tinyurl.com/26wxlue3',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge top VEDETTE VT16022',
#   'note': 'no review',
#   'prix': '314681 CFA',
#   'image': 'https://tinyurl.com/2y8cwj9p',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top CANDY CSTG482DE147',
#   'note': '5/5 (1 avis clients)',
#   'prix': '248848 CFA',
#   'image': 'https://tinyurl.com/2xpvmvja',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4130SP',
#   'note': 'no review',
#   'prix': '361423 CFA',
#   'image': 'https://tinyurl.com/2y387ccv',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW7F3921RB',
#   'note': 'no review',
#   'prix': '499672 CFA',
#   'image': 'https://tinyurl.com/25hsgb4p',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge séchant ELECTROLUX EW7W3922RB',
#   'note': '5/5 (1 avis clients)',
#   'prix': '526005 CFA',
#   'image': 'https://tinyurl.com/26wsvkj2',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot FAURE FWF84404DD',
#   'note': 'no review',
#   'prix': '319948 CFA',
#   'image': 'https://tinyurl.com/25eeahht',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SHARP ESHFB7143WD',
#   'note': 'no review',
#   'prix': '216590 CFA',
#   'image': 'https://tinyurl.com/2xqqwlo9',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F3112RC',
#   'note': 'no review',
#   'prix': '417381 CFA',
#   'image': 'https://tinyurl.com/263nvpf3',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL W6W845WBFR',
#   'note': 'no review',
#   'prix': '485847 CFA',
#   'image': 'https://tinyurl.com/2c59cqgq',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F94V40WH',
#   'note': 'no review',
#   'prix': '371298 CFA',
#   'image': 'https://tinyurl.com/23vbg3uc',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot ELECTROLUX EW6F1495FC',
#   'note': 'no review',
#   'prix': '407506 CFA',
#   'image': 'https://tinyurl.com/23og4gnk',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot FAURE FWF7474B52',
#   'note': 'no review',
#   'prix': '302173 CFA',
#   'image': 'https://tinyurl.com/26jqfm99',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top BRANDT BT16524Q',
#   'note': 'no review',
#   'prix': '328506 CFA',
#   'image': 'https://tinyurl.com/2btneqx3',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BEKO WTV8712BS1W',
#   'note': 'no review',
#   'prix': '272548 CFA',
#   'image': 'https://tinyurl.com/25vc44hy',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BEKO LLF11W2',
#   'note': 'no review',
#   'prix': '349573 CFA',
#   'image': 'https://tinyurl.com/22oym4rq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot BOSCH WUU28T19FF',
#   'note': '5/5 (1 avis clients)',
#   'prix': '405531 CFA',
#   'image': 'https://tinyurl.com/26x2nhqw',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'Lave-linge séchant ELECTROLUX EWW1686WS',
#   'note': 'no review',
#   'prix': '476630 CFA',
#   'image': 'https://tinyurl.com/24el2epq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBD10469BSVFR',
#   'note': 'no review',
#   'prix': '429889 CFA',
#   'image': 'https://tinyurl.com/27cvezss',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal ELECTROLUX EW6F4805CR',
#   'note': 'no review',
#   'prix': '341673 CFA',
#   'image': 'https://tinyurl.com/22nkh9pa',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot SHARP ESNFB914AWB',
#   'note': '5/5 (2 avis clients)',
#   'prix': '296248 CFA',
#   'image': 'https://tinyurl.com/2dyshgn8',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot WHIRLPOOL FFBS8469WVFR',
#   'note': 'no review',
#   'prix': '347598 CFA',
#   'image': 'https://tinyurl.com/29rz2hyx',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BOSCH WAX32M01FF',
#   'note': 'no review',
#   'prix': '657671 CFA',
#   'image': 'https://tinyurl.com/227auvtt',
#   'location': 'Guediawaye, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW90T4020EH',
#   'note': 'no review',
#   'prix': '340356 CFA',
#   'image': 'https://tinyurl.com/2356h7aq',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal SAMSUNG WW11BB504DAWS3',
#   'note': 'no review',
#   'prix': '558263 CFA',
#   'image': 'https://tinyurl.com/23ppjyv2',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge frontal LG F14V52IXS',
#   'note': 'no review',
#   'prix': '464122 CFA',
#   'image': 'https://tinyurl.com/2bknbudu',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge top INDESIT BTWPS62400FRN',
#   'note': 'no review',
#   'prix': '262673 CFA',
#   'image': 'https://tinyurl.com/25u2mj9j',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot SAMSUNG WW11BB704DGWS3',
#   'note': '5/5 (1 avis clients)',
#   'prix': '522055 CFA',
#   'image': 'https://tinyurl.com/25nhv3l6',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot MIELE WSA023',
#   'note': 'no review',
#   'prix': '624755 CFA',
#   'image': 'https://tinyurl.com/2bxeu7cx',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Lave-linge hublot MIELE WCD660',
#   'note': 'no review',
#   'prix': '917053 CFA',
#   'image': 'https://tinyurl.com/28oxyg3m',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Lave-linge hublot BEKO WUE6612W1W',
#   'note': 'no review',
#   'prix': '221857 CFA',
#   'image': 'https://tinyurl.com/2b5jme8r',
#   'location': 'Almadies, Dakar, Sénégal'},
#  {'nom': 'Package LG 4.5 Cu. Ft. High',
#   'image': 'https://tinyurl.com/24lvt6d2',
#   'prix': '785895 CFA',
#   'note': 'User rating, 4.5 out of 5 stars with 1674 reviews.',
#   'location': 'Dakar, Sénégal'},
#  {'nom': 'Ninja 7 Style Espresso & Coffee',
#   'image': 'https://tinyurl.com/22qzar3k',
#   'prix': '120395 CFA',
#   'note': 'Rating 4.6 out of 5 stars with 300 reviews',
#   'location': 'Dakar Plateau, Dakar, Sénégal'},
#  {'nom': 'KingHome 150 Sq. Ft. 5,000 BTU',
#   'image': 'https://tinyurl.com/2dgqes54',
#   'prix': '114345 CFA',
#   'note': 'Rating 4 out of 5 stars with 2 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'LG 30" Built-In Electric Convection Combination',
#   'image': 'https://tinyurl.com/2cklfxy5',
#   'prix': '1814395 CFA',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'BISSELL CrossWave Pet Pro All-in-One Multi-Surface',
#   'image': 'https://tinyurl.com/2dlv72yv',
#   'prix': '199045 CFA',
#   'note': 'Rating 4.3 out of 5 stars with 1251 reviews',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Package Thermador ProHarmony 5.0 Cu. Ft.',
#   'image': 'https://tinyurl.com/2asbf9q7',
#   'prix': '7258790 CFA',
#   'note': 'User rating, 4.2 out of 5 stars with 29 reviews.',
#   'location': 'Grand Yoff, Dakar, Sénégal'},
#  {'nom': 'Viking Professional 5 Series Quiet Cool',
#   'image': 'https://tinyurl.com/2yhhueo3',
#   'prix': '6811695 CFA',
#   'note': 'Rating 4.3 out of 5 stars with 4 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Honeywell Home QuietSet Tower Fan White',
#   'image': 'https://tinyurl.com/28qk7stk',
#   'prix': '36905 CFA',
#   'note': 'Rating 4.4 out of 5 stars with 4135 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'LG 27 Cu. Ft. Side-by-Side Smart',
#   'image': 'https://tinyurl.com/22d8pepj',
#   'prix': '1027895 CFA',
#   'note': 'Rating 4.6 out of 5 stars with 514 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Samsung 28 cu. ft. Side-by-Side Refrigerator',
#   'image': 'https://tinyurl.com/23hwnad8',
#   'prix': '664895 CFA',
#   'note': 'Rating 4.7 out of 5 stars with 476 reviews',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Panasonic HomeCHEF .7 Cu. Ft. 7-in-1',
#   'image': 'https://tinyurl.com/2aw6pvfj',
#   'prix': '301895 CFA',
#   'note': 'Rating 4.1 out of 5 stars with 33 reviews',
#   'location': "Patte d'oie, Dakar, Sénégal"},
#  {'nom': 'Shark Matrix Self-Emptying Robot Vacuum with',
#   'image': 'https://tinyurl.com/24rsdcuo',
#   'prix': '301895 CFA',
#   'note': 'Rating 5 out of 5 stars with 1 reviewfalse',
#   'location': 'Ouakam, Dakar, Sénégal'},
#  {'nom': 'Package Bosch 800 Series 20.5 Cu.',
#   'image': 'https://tinyurl.com/2885u9lp',
#   'prix': '7271495 CFA',
#   'note': 'User rating, 4.6 out of 5 stars with 341 reviews.',
#   'location': "Patte d'oie, Dakar, Sénégal"}]
